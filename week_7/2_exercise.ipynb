# %% [markdown]
# # Exercise: Choose a new target and build a model
#
# Choose one of the following targets:
#
# * `indoor_temp_c`
# * `power_consumption_kw`
# * `indoor_humidity_pct`
#
# Predict the chosen variable **30 minutes** ahead.
#
# **Requirements**
# * Use a time-based split
# * Create lag features for at least 3 variables
# * Create at least one rolling mean feature
# * Train at least two different models
# * Report MAE and RMSE
# * Plot predictions vs ground truth for a short time window
# * Explain which features were most important
#
# **Reflection**
# * Why did you choose this target?
# * Which sensors were most useful?
# * Which variables were surprisingly unhelpful?
# * How would you improve the model further?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('./data/building_multisensor_2years_30min_v2.csv')
