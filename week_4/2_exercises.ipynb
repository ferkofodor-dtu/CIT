# %% [markdown]
# # Exercise: Explore and Visualize a New Dataset
#
# ## Goal
#
# In this exercise, you will **explore a dataset that was NOT used in the demonstrations** and create visualizations to better understand the data.
#
# Unlike the previous examples where the plot type was specified, here you will need to:
#
# - **explore the dataset yourself**
# - **decide which plots are appropriate**
# - **possibly engineer new features**
# - **visualize your findings**
#
# You may use **Matplotlib**, **Seaborn**, or a combination of both depending on which library is more convenient.
#
# ---
#
# # Step 1 - Choose a dataset
#
# Use one of the following Seaborn datasets that we have **not used in the demonstrations**.
#
# Suggested datasets:
#
# | Dataset | Description |
# |---|---|
# | `diamonds` | prices and characteristics of diamonds |
# | `titanic` | passenger information from the Titanic |
# | `mpg` | fuel efficiency of cars |
# | `planets` | discoveries of exoplanets |
#
# Load a dataset:
#
# ```python
# import seaborn as sns
# import pandas as pd
# import matplotlib.pyplot as plt
#
# sns.set_theme(style="whitegrid")
#
# df = sns.load_dataset("titanic")
# df.head()

# %%
# Your code goes here

# %% [markdown]
# # Step 2 - Explore the dataset
#
# Before creating visualizations, inspect the dataset carefully.
#
# Useful commands include:
# ```python
# df.head()  # View the first few rows of the dataset
#
# df.info()  # Get an overview of the dataset
#
# df.describe()  # Get summary statistics for numerical columns
#
# df['column_name'].value_counts()  # Get counts of unique values in a categorical column
# ```
# Identify interesting features and relationships in the data that you want to visualize.

# %%
# Your code goes here

# %% [markdown]
# # Step 3 - Feature Engineering (Recommended)
#
# Before plotting, try to create at least one new feature.
#
# Feature engineering often helps reveal interesting patterns.
#
# ### Example ideas
#
# These are only suggestions — feel free to invent your own.
#
# **Titanic dataset**
# ```python
# df["family_size"] = df["sibsp"] + df["parch"] + 1
# df["is_alone"] = df["family_size"] == 1
# ```
# **Diamonds dataset**
# ```python
# df["price_per_carat"] = df["price"] / df["carat"]
# ```
# **MPG dataset**
# ```python
# df["power_to_weight"] = df["horsepower"] / df["weight"]
# ```
# **Planets dataset**
# ```python
# df["log_mass"] = np.log(df["mass"])
# df["discovery_decade"] = (df["year"] // 10) * 10
# ```
#
# You may also try:
#
# * binning variables
# * creating ratios
# * grouping categories
# * combining variables

# %%
# Your code goes here

# %% [markdown]
# # Step 4 - Create four visualizations
#
# Create **four different plots** that help explore the dataset.
# Choose the plot type depending on the question you want to answer.
#
# Your plots **must include at least three different plot types.**
#
# | Plot         | Typical use                                  |
# | ------------ | -------------------------------------------- |
# | Scatter plot | relationship between two numerical variables |
# | Histogram    | distribution of a variable                   |
# | Box plot     | compare distributions across categories      |
# | Bar plot     | compare averages across groups               |
# | Violin plot  | distribution + density                       |
# | Heatmap      | correlation matrix                           |
# | Line plot    | trend over time                              |

# %% [markdown]
# ## Example plot idea
#
# **Correlation heatmap**
# ```python
# corr = df.corr(numeric_only=True)
# sns.heatmap(corr, cmap="coolwarm", center=0)
# ```
#
#
# **You can combine the plots into a single figure** using `plt.subplots()`
# ```python
# fig, axes = plt.subplots(2, 2, figsize=(15, 10))
# # Plot 1 : axes[0, 0] (top-left)
# # Plot 2 : axes[0, 1] (top-right)
# # Plot 3 : axes[1, 0] (bottom-left)
# # Plot 4 : axes[1, 1] (bottom-right)
# ```

# %%
# Your code goes here

# %% [markdown]
# # Step 5 - Interpretation
#
# Under each plot, write 1–2 sentences explaining what you observe.
#
# For example:
# - What patterns do you notice?
# - Are there any outliers?
# - Are some categories clearly different?
# - Are some variables correlated?
#
# Example interpretation:
# ```
# The scatter plot suggests that higher fares tend to be associated with higher passenger ages, although the relationship is weak.

# %% [markdown]
# # Reflection
#
# At the end of the exercise, answer the following:
# - Which plot helped you understand the dataset the most?
# - Did feature engineering reveal any new patterns?
# - When did you prefer using Seaborn instead of Matplotlib?
# - What additional visualization would you create if you had more time?
